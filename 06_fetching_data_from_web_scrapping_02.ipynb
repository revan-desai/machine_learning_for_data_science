# %% [markdown]
# <a href="https://colab.research.google.com/github/revan-desai/machine_learning_for_data_science/blob/main/06_fetching_data_from_web_scrapping_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install bs4

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
webpage=requests.get('https://www.ambitionbox.com/list-of-companies',headers=headers).text

# %%
soup=BeautifulSoup(webpage,'lxml')

# %%
company=soup.find_all('div',class_="companyCardWrapper__companyDetails")

# %%
name=[]
rating=[]
reviews=[]
companyinfo=[]


for i in company:
  name.append(i.find('h2').text.strip())
  rating.append(i.find('span', class_="companyCardWrapper__companyRatingValue").text.strip())
  # reviews.append(i.find('span', class_="companyCardWrapper__ActionCount").text.strip())
  companyinfo.append(i.find('span', class_="companyCardWrapper__interLinking").text.strip())

name
rating
companyinfo
# Out:
# ['IT Services & Consulting | 1 Lakh+ Employees | Public | 55 years old | Mumbai +284 more',
#  'IT Services & Consulting | 1 Lakh+ Employees | Public | 34 years old | Dublin +141 more',
#  'IT Services & Consulting | 1 Lakh+ Employees | Forbes Global 2000 | 29 years old | Teaneck. New Jersey. +111 more',
#  'IT Services & Consulting | 1 Lakh+ Employees | Public | 78 years old | Bangalore/Bengaluru +246 more',
#  'Banking | 1 Lakh+ Employees | Public | 29 years old | Mumbai +1199 more',
#  'Banking | 1 Lakh+ Employees | Public | 29 years old | Mumbai +1432 more',
#  'IT Services & Consulting | 1 Lakh+ Employees | Public | 42 years old | Bengaluru/Bangalore +136 more',
#  'IT Services & Consulting | 1 Lakh+ Employees | Public | 56 years old | Paris +87 more',
#  'IT Services & Consulting | 1 Lakh+ Employees | Public | 37 years old | Pune +236 more',
#  'IT Services & Consulting | 1 Lakh+ Employees | Public | 32 years old | Noida +154 more',
# ...

# %%
d={'name':name,'rating':rating,'companyinfo':companyinfo}

df=pd.DataFrame(d)

df.head()
# Out:
#          name rating                                        companyinfo
# 0         TCS    3.8  IT Services & Consulting | 1 Lakh+ Employees |...
# 1   Accenture    4.1  IT Services & Consulting | 1 Lakh+ Employees |...
# 2   Cognizant    3.9  IT Services & Consulting | 1 Lakh+ Employees |...
# 3       Wipro    3.8  IT Services & Consulting | 1 Lakh+ Employees |...
# 4  ICICI Bank    4.0  Banking | 1 Lakh+ Employees | Public | 29 year...

# %%
df.to_csv('ambitionbox.csv')    # converting to csv file
