# %% [markdown]
# <a href="https://colab.research.google.com/github/revan-desai/machine_learning_for_data_science/blob/main/working_csv_files.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df=pd.read_csv('/content/iplmatches.csv')
df.head(1)
# Out:
#    id  season       city        date                team1  \
# 0   1    2017  Hyderabad  2017-04-05  Sunrisers Hyderabad
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
#
#    result  dl_applied               winner  win_by_runs  win_by_wickets  \
# 0  normal           0  Sunrisers Hyderabad           35               0
#
#   player_of_match                                      venue      umpire1  \
# 0    Yuvraj Singh  Rajiv Gandhi International Stadium, Uppal  AY Dandekar
#
#     umpire2  umpire3
# 0  NJ Llong      NaN

# %% [markdown]
# ## working with tsv files tab separated values

# %%
df=pd.read_csv('/content/iplmatches.csv',sep='\t')

# %%
df.head(2)
# Out:
#    id  season       city        date                team1  \
# 0   1    2017  Hyderabad  2017-04-05  Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06       Mumbai Indians
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
#
#    result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# 0  normal           0     Sunrisers Hyderabad           35               0
# 1  normal           0  Rising Pune Supergiant            0               7
#
#   player_of_match                                      venue         umpire1  \
# 0    Yuvraj Singh  Rajiv Gandhi International Stadium, Uppal     AY Dandekar
# 1       SPD Smith    Maharashtra Cricket Association Stadium  A Nand Kishore
#
#     umpire2  umpire3
# 0  NJ Llong      NaN
# 1    S Ravi      NaN

# %% [markdown]
# ## 3.now if you want to make id as dataframe id

# %%
df=pd.read_csv('/content/iplmatches.csv',index_col='id')
df.head(2)
# Out:
#     season       city        date                team1  \
# id
# 1     2017  Hyderabad  2017-04-05  Sunrisers Hyderabad
# 2     2017       Pune  2017-04-06       Mumbai Indians
#
#                           team2                  toss_winner toss_decision  \
# id
# 1   Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 2        Rising Pune Supergiant       Rising Pune Supergiant         field
#
#     result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# id
# 1   normal           0     Sunrisers Hyderabad           35               0
# 2   normal           0  Rising Pune Supergiant            0               7
#
#    player_of_match                                      venue         umpire1  \
# id
# 1     Yuvraj Singh  Rajiv Gandhi International Stadium, Uppal     AY Dandekar
# 2        SPD Smith    Maharashtra Cricket Association Stadium  A Nand Kishore
#
#      umpire2  umpire3
# id
# 1   NJ Llong      NaN
# 2     S Ravi      NaN

# %% [markdown]
# ## suppose all columns are placed at 1st row and if you want to make those values as column name then use

# %%
pd.read_csv('/content/iplmatches.csv',header=1)

# %% [markdown]
# ## 5.usecols

# %%
pd.read_csv('/content/iplmatches.csv',usecols=['city','team1']).head(2)
# Out:
#         city                team1
# 0  Hyderabad  Sunrisers Hyderabad
# 1       Pune       Mumbai Indians

# %% [markdown]
# ## 6. skip rows

# %%
pd.read_csv('/content/iplmatches.csv',skiprows=5).head(2)
# Out:
#    5  2017  Bangalore  2017-04-08 Royal Challengers Bangalore  \
# 0  6  2017  Hyderabad  2017-04-09               Gujarat Lions
# 1  7  2017     Mumbai  2017-04-09       Kolkata Knight Riders
#
#       Delhi Daredevils Royal Challengers Bangalore.1    bat  normal  0  \
# 0  Sunrisers Hyderabad           Sunrisers Hyderabad  field  normal  0
# 1       Mumbai Indians                Mumbai Indians  field  normal  0
#
#   Royal Challengers Bangalore.2  15  0.1    KM Jadhav  \
# 0           Sunrisers Hyderabad   0    9  Rashid Khan
# 1                Mumbai Indians   0    4       N Rana
#
#                        M Chinnaswamy Stadium  Unnamed: 15 Unnamed: 16  \
# 0  Rajiv Gandhi International Stadium, Uppal   A Deshmukh    NJ Llong
# 1                           Wankhede Stadium  Nitin Menon   CK Nandan
#
#    Unnamed: 17
# 0          NaN
# 1          NaN

# %% [markdown]
# ## while working with huge data use nrows

# %%
pd.read_csv('/content/iplmatches.csv',nrows=5)
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %% [markdown]
# ## skip bad lines
# ## you can skip rows with errors

# %%
pd.read_csv('/content/iplmatches.csv',error_bad_lines=False).head(2)
# Out:
# <ipython-input-25-df97ee4f8780>:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   pd.read_csv('/content/iplmatches.csv',error_bad_lines=False).head(2)
#    id  season       city        date                team1  \
# 0   1    2017  Hyderabad  2017-04-05  Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06       Mumbai Indians
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
#
#    result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# 0  normal           0     Sunrisers Hyderabad           35               0
# 1  normal           0  Rising Pune Supergiant            0               7
#
#   player_of_match                                      venue         umpire1  \
# ...

# %% [markdown]
# ## data type paramter

# %%
pd.read_csv('/content/iplmatches.csv',dtype={'dl_applied':float}).head(2)
# you can verify usig df.info()
# Out:
#    id  season       city        date                team1  \
# 0   1    2017  Hyderabad  2017-04-05  Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06       Mumbai Indians
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
#
#    result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# 0  normal         0.0     Sunrisers Hyderabad           35               0
# 1  normal         0.0  Rising Pune Supergiant            0               7
#
#   player_of_match                                      venue         umpire1  \
# 0    Yuvraj Singh  Rajiv Gandhi International Stadium, Uppal     AY Dandekar
# 1       SPD Smith    Maharashtra Cricket Association Stadium  A Nand Kishore
#
#     umpire2  umpire3
# 0  NJ Llong      NaN
# 1    S Ravi      NaN

# %% [markdown]
# ## handling dates columns

# %%
df=pd.read_csv('/content/iplmatches.csv',parse_dates=['date']).head(2)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               2 non-null      int64
#  1   season           2 non-null      int64
#  2   city             2 non-null      object
#  3   date             2 non-null      datetime64[ns]
#  4   team1            2 non-null      object
#  5   team2            2 non-null      object
#  6   toss_winner      2 non-null      object
#  7   toss_decision    2 non-null      object
#  8   result           2 non-null      object
#  9   dl_applied       2 non-null      int64
#  10  winner           2 non-null      object
#  11  win_by_runs      2 non-null      int64
#  12  win_by_wickets   2 non-null      int64
#  13  player_of_match  2 non-null      object
#  14  venue            2 non-null      object
#  15  umpire1          2 non-null      object
# ...

# %% [markdown]
# ## suppose 3 columns month ,date,year you want make it as one single date column

# %%
#df['date']=pd.to_datetime(df[['month','year','day']])

# %% [markdown]
# ## na_values parameter
#
# ## suppose some row contains % and - instead of NaN then

# %%
df=pd.read_csv('/content/iplmatches.csv',na_values=['-','%'])

# %% [markdown]
# ## dealing with data with huge rows

# %%
dfs=pd.read_csv('/content/iplmatches.csv',chunksize=100)

for i in dfs:
  print(i.shape)

print(i.head(2))
# Out:
# (100, 18)
# (100, 18)
# (100, 18)
# (100, 18)
# (100, 18)
# (100, 18)
# (36, 18)
#       id  season   city        date                    team1  \
# 600  601    2016   Pune  2016-04-29  Rising Pune Supergiants
# 601  602    2016  Delhi  2016-04-30         Delhi Daredevils
#
#                      team2            toss_winner toss_decision  result  \
# 600          Gujarat Lions          Gujarat Lions         field  normal
# 601  Kolkata Knight Riders  Kolkata Knight Riders         field  normal
#
#      dl_applied            winner  win_by_runs  win_by_wickets  \
# 600           0     Gujarat Lions            0               3
# 601           0  Delhi Daredevils           27               0
#
#     player_of_match                                    venue  \
# 600        DR Smith  Maharashtra Cricket Association Stadium
# 601   CR Brathwaite                         Feroz Shah Kotla
#
#                    umpire1       umpire2  umpire3
# ...
